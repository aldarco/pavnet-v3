# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## baseband method

# %%
data = pd.read_csv("/home/aldo/ANTAR_amplitude_2026-01-06 00:00:07-to-2026-01-06 00:00:07.csv", 
                   parse_dates=True, index_col=0)

# %%
data.head()
# Out:
#                           NPM       NAA       NLK       NLM       NAU
# DateTime
# 2026-01-06 00:00:07  0.008569  0.002968  0.002852  0.002852  0.001116
# 2026-01-06 00:00:17  0.008534  0.003128  0.003134  0.003134  0.001125
# 2026-01-06 00:00:27  0.008564  0.003006  0.003030  0.003030  0.001106
# 2026-01-06 00:00:36  0.008498  0.003018  0.002989  0.002989  0.001052
# 2026-01-06 00:00:46  0.008592  0.002967  0.002908  0.002908  0.001058

# %%
# %matplotlib widget

# %%
fig, ax = plt.subplots()
data.NAA.plot(ax=ax)
# Out:
# <Axes: xlabel='DateTime'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## the method of FFT and peak selection

# %%
data0 = pd.read_csv("/data/pavnet/2026/PIURA/data/PIU_AMPLITUDE_2026-01-06-to-2026-01-20.csv", 
                   parse_dates=True, index_col=0)

# %%
fig, ax = plt.subplots()
data0["NAA"].plot(alpha=0.2)
data0["NAA-filt"].plot(color="blue")
# Out:
# <Axes: >
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close("all")
