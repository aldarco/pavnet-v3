# %%
import pandas as pd
import urllib.parse as parse
import sys

# %%
goes_satellite = 19
datasets = {
    "xray-flux": f"dap/noaa_goes{goes_satellite}_xrs_1m", 
    "particle-flux": f"dap/goesp_part_flux_P5M", # proton and electron
    "magnetometer": f"dap/goesp_mag_p1m",
    "planetary-kp": f"dap2/iswa_noaa_kp_P3H",  #dap2/potsdam_kp iswa_noaa_kp_P3H.
    "particle-flux-sat": f"dap/noaa_goes{goes_satellite}_epead_proton_flux_b_5m" 
}

# %%
def get_data(dataset_id, tstart, tend=None):
    baseurl = f"https://lasp.colorado.edu/space-weather-portal/latis/{dataset_id}.csv?"

    tstart_enc = parse.quote(tstart)
    query = f"time>={tstart_enc}"
    if tend:
        tend_enc = parse.quote(tend)
        query += f"&time<{tend_enc}"
    full_url = baseurl + query
    print(f"Requesting: {full_url}")
    
    try: 
        df = pd.read_csv(full_url, storage_options={'User-Agent': 'Mozilla/5.0'})
        return df
    except Exception as e:
        print(f"Error downloading {dataset_id}: {e}")     
        return None

# %%
if __name__ == "__main__":
    # test demo 
    t1 = "2026-01-01T08:00:00"
    t2 = "2026-01-01T16:00:00"
    # dataset = sys.argv[1]
    # if dataset=="-h":
    #     print("")
    # https://lasp.colorado.edu/space-weather-portal/latis/dap2/iswa_noaa_kp_P3H.csv?time>=2024-03-01T00:00:00&time<2024-03-02T00:00:00
    #df = get_data(datasets["xray-flux"], t1, t2)
    df = get_data(datasets["planetary-kp"], t1, t2)
# Out:
# Requesting: https://lasp.colorado.edu/space-weather-portal/latis/dap2/iswa_noaa_kp_P3H.csv?time>=2026-01-01T08%3A00%3A00&time<2026-01-01T16%3A00%3A00
# Error downloading dap2/iswa_noaa_kp_P3H: HTTP Error 400: Bad Request

# %%
import gc

# %%
gc.collect()
# Out:
# 809

# %%
df
# Out:
#       time (seconds since 2000-01-01 12:00:00)  shortwave (W/m^2)  \
# 0                                  820526400.0       3.191911e-08
# 1                                  820526460.0       3.456563e-08
# 2                                  820526520.0       3.909127e-08
# 3                                  820526580.0       3.743282e-08
# 4                                  820526640.0       3.622674e-08
# ...                                        ...                ...
# 1435                               820612500.0       1.873118e-08
# 1436                               820612560.0       1.860978e-08
# 1437                               820612620.0       1.842908e-08
# 1438                               820612680.0       1.972291e-08
# 1439                               820612740.0       1.904476e-08
#
#       longwave (W/m^2)  shortwave_flag  longwave_flag  \
# 0             0.000002               0              0
# 1             0.000002               0              0
# 2             0.000002               0              0
# 3             0.000002               0              0
# 4             0.000002               0              0
# ...                ...             ...            ...
# 1435          0.000001               0              0
# 1436          0.000001               0              0
# 1437          0.000001               0              0
# 1438          0.000001               0              0
# 1439          0.000001               0              0
#
#       shortwave_masked (W/m^2)  longwave_masked (W/m^2)
# 0                 3.191911e-08                 0.000002
# 1                 3.456563e-08                 0.000002
# 2                 3.909127e-08                 0.000002
# 3                 3.743282e-08                 0.000002
# 4                 3.622674e-08                 0.000002
# ...                        ...                      ...
# 1435              1.873118e-08                 0.000001
# 1436              1.860978e-08                 0.000001
# 1437              1.842908e-08                 0.000001
# 1438              1.972291e-08                 0.000001
# 1439              1.904476e-08                 0.000001
#
# [1440 rows x 7 columns]
